# %%
from tkinter import *

# %%
win = Tk()
win.title("**** Wscube Tech *****")   # apply title
#win.iconbitmap(r".iso")     # loga
win.attributes("-alpha",1)  # transparency
#win.config(bg="red")      # bg color
win['bg']="yellow"
win.mainloop()
